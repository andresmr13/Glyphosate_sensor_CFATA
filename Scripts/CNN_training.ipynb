# %% [markdown]
# ## This model version is used to train data from a glyphosate using data from the Hammamatsu spec sensor.
# ### Input data = 100 bands (50 from the dispersion spectrum + 50 from the emission spectrum)
# ### Number of samples at this point is 63 (in the range 0 to 1000 ppm) per group. Three groups of samples were obtained 1 on 10-17-25, and 2 on 10-18-25.

# %%
# Import modules
import os

# --- Step 1: Force CPU Usage (MUST be first) ---
# This ensures deterministic computations by avoiding the MPS GPU backend.
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf
import numpy as np
import random

# --- Step 2: Set All Random Seeds ---
seed_value = 42
os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

print("Forcing CPU-only execution for reproducibility. ✅")
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

from tensorflow.keras import layers, models
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler, RobustScaler
# from tensorflow.keras.callbacks import EarlyStopping

import csv
# Misc
# from itertools import islice
# import plotly.express as px
# Out:
# Forcing CPU-only execution for reproducibility. ✅
# Num GPUs Available:  0

# %% [markdown]
# ## Inference functions

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy import stats

def get_metrics(y_test,y_pred):
    # Evaluation metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    #r2 = r2_score(y_test, y_pred)
    regression_result = stats.linregress(y_test, y_pred)
    r2 = regression_result.rvalue ** 2

    print(f"Mean Absolute Error (MAE): {mae:.3f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
    print(f"R-squared (R2): {r2:.3f}")
    
    return(mae,rmse,r2)

def model_predict(dynamic_filename,X_test_scaled,y_test):
    # Load the saved model from the file
    print(f"Loading model from: {dynamic_filename}")
    # 2. Cargar el modelo
    loaded_model = models.load_model('/Users/andresmr/Documents/Glyphosate_sensor_CFATA/Scripts/'+dynamic_filename)
    print("Model loaded successfully.")

    X_test = X_test_scaled
    # Use the loaded model to make predictions on the test data
    y_pred = loaded_model.predict(X_test)

    # The output of .predict() is often a 2D array, so we flatten it to a 1D array
    y_pred = y_pred.flatten()

    # LOD & LOQ
    is_blank = (y_test <0.001)
    y_pred_blanks = y_pred[is_blank]
    print(y_pred_blanks)
    mu_blank = np.mean(y_pred_blanks)
  
    sigma_blank = np.std(y_pred_blanks) 
    print(mu_blank,sigma_blank)
    lod = mu_blank + (3 * sigma_blank)
    loq = mu_blank + (10 * sigma_blank)

    print(f"(LOD): {lod:.4f} ppm")
    print(f"(LOQ): {loq:.4f} ppm")

    # Evaluation metrics
    mae,rmse,r2 = get_metrics(y_test,y_pred)
    
    # 2. Create the plot
    fig, ax = plt.subplots(figsize=(8, 8))

    # Scatter plot of actual vs. predicted values
    ax.scatter(y_test, y_pred, alpha=0.6, edgecolors="w", label='Predictions')

    # Add a line for perfect predictions (y=x)
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
        np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
    ]
    ax.plot(lims, lims, 'r--', alpha=0.75, zorder=0, label='Perfect Predictions')

    # 3. Add metrics to the plot
    # Using LaTeX for R^2
    metrics_text = (
        f"$R^2$ = {r2:.3f}\n"
        f"MAE = {mae:.3f}\n"
        f"RMSE = {rmse:.3f}"
    )
    # Place text box in the top-left corner
    ax.text(0.05, 0.95, metrics_text, transform=ax.transAxes, fontsize=12,
            verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='wheat', alpha=0.5))

    # 4. Final plot settings
    ax.set_xlabel("Actual Values (y_test)", fontsize=12)
    ax.set_ylabel("Predicted Values (y_pred)", fontsize=12)
    ax.set_title("Actual vs. Predicted Values", fontsize=16)
    ax.set_aspect('equal', adjustable='box')
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Read main file with samples

# %%
# Create augmentations with original data

# File path with measurements 
# file_path = '/Users/andresmr/Documents/Glyphosate_sensor_CFATA/ESP32_code/samples/10-21-2025_G1_R3.csv'
file_path = '/Users/andresmr/Documents/Glyphosate_sensor_CFATA/samples/G1G2R1.csv'
# Open file with data.
with open(file_path, 'r') as file:
    reader = csv.reader(file)
    n = 0
    data = []
    for i,row in enumerate(reader):
        data.append(row)
        # if n<1015:
        #     data.append(row)
        # n+=1
#len(data)

split = [] # The data from '10-21-2025_G1_R1.csv' will only be used for training and validation
split.append(len(data)) # original samples
split.append(len(data)) # train and val set
split.append((len(data)*0.2)/len(data)) # val set percentage
split.append(0) # test set

# Shuffle the rows of the data list in-place
random.shuffle(data)

print(len(data))
print(split)
# Out:
# 261
# [261, 261, 0.2, 0]

# %% [markdown]
# ### Augmentations for training data

# %%
# Create augmentations with original data

# File path with measurements; group one with one sample per concentration, three replicate measurements
# file_path = '/Users/andresmr/Documents/Glyphosate_sensor_CFATA/ESP32_code/samples/10-21-2025_G1_R3.csv'
file_path = '/Users/andresmr/Documents/Glyphosate_sensor_CFATA/samples/G1G2R1.csv'

# Create list variables
nombres = []
invalues = []
outvalues = []

# Create list for augmentations
filaau = ["A"] * 110
aug = []

variants = 7 # 7 m
noise1 = 0.06 # 0.05
noise2 = 0.03 # 0.02
# noise1b = -0.05
# noise2b = -0.02
# Open file with data
with open(file_path, 'r') as file:
    reader = csv.reader(file)
    n = 0
    for row in reader:
        if n<(split[1]-1):
            filaau[1]=row[1] # row[1] is glyphosate concentration (true)
        # Start augmentations 
            # +-X% noise augmentation (m variants per sample)
            for j in range(0,variants):
              filaau[0]=row[0]+"_"+ str(j) # filaau contains string name sample + j-index (m variants j-indices per row/sample).
              # first block of x data
              for i in range(3,53): # Iterate over column 3 to 53 in csv per j iteration (m variants j-indices)
                filaau[i]=float(row[i])
                filaau[i]=filaau[i]*random.uniform(1-noise1, 1-noise1)
                #filaau[i] = filaau[i] + random.uniform(-noise1, noise1)
              filaau[53]='-'
              # second block of x data
              for i in range(54,104):
                filaau[i]=float(row[i])
                filaau[i]=filaau[i]*random.uniform(1-noise1, 1-noise1)
              # # Save augmentation
              aug.append(filaau.copy())

            #+-X noise augmentations%
            for j in range(variants,variants*2):
              filaau[0]=row[0]+"_"+ str(j)
              for i in range(3,53):
                filaau[i]=float(row[i])
                filaau[i]=filaau[i]*random.uniform(1-noise2, 1-noise2)
              filaau[53]='-'
              # Second block of data
              for i in range(54,104):
                filaau[i]=float(row[i])
                filaau[i]=filaau[i]*random.uniform(1-noise2, 1-noise2)
              aug.append(filaau.copy())
        n+=1
len(data), split[1], len(aug)
# Out:
# (261, 261, 3640)

# %% [markdown]
# ## X and y data

# %%
# X and y data lists
_inputs = []
_targets = []

# Add first block of data (original)
for i in range(int(split[1])):
        row_data = []
        for j in range(3,104):
                if j!= 53:
                        row_data.append(float(data[i][j]))
        _inputs.append(row_data)
        _targets.append(float(data[i][1]))
# Add second block of data (augmentations for main and second file)
for i in range(len(aug)):
        row_data = []
        for j in range(3,104):
                if j!= 53:                        
                        row_data.append(float(aug[i][j]))
        _inputs.append(row_data)
        _targets.append(float(aug[i][1]))

# Convert list to arrays
X_data = np.array(_inputs)
y_data= np.array(_targets)

print(len(X_data), len(y_data))
print(len(data))
print(len(X_data[0]))

# Data normalization
#scaler = StandardScaler()
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_data)
print(split[2])
# Out:
# 3901 3901
# 261
# 100
# 0.2

# %% [markdown]
# ## Use CNN

# %%
import time

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train_scaled, y_data, test_size=split[2], random_state=42
)

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

# Obtener la forma de entrada
input_shape = (X_train.shape[1], X_train.shape[2]) # (100, 1)

# --- Definición del Modelo 1D-CNN ---
print(f"\nConstruyendo modelo 1D-CNN con input_shape: {input_shape}")
model_cnn = models.Sequential([
    # Capa 1: Detecta patrones locales (tamaño 5 bandas)
    layers.Conv1D(filters=32, kernel_size=40, activation='relu', input_shape=input_shape),
    # Capa 2: Resume los patrones encontrados, reduciendo la secuencia
    layers.MaxPooling1D(pool_size=2),
    
    # Capa 3: Detecta patrones de patrones (más complejos)
    layers.Conv1D(filters=64, kernel_size=5, activation='relu'),
    # Capa 4: Vuelve a resumir
    layers.MaxPooling1D(pool_size=2),
    
    # Capa 5: Aplana los mapas de características 2D a un vector 1D
    layers.Flatten(),
    
    # Capa 6: Una capa densa para interpretar los patrones
    layers.Dense(64, activation='relu'),
    # Capa 7: Dropout para prevenir sobreajuste (overfitting)
    layers.Dropout(0.3),
    
    # Capa 8: Capa de salida para regresión (predicción de concentración)
    layers.Dense(1, activation='linear')
])

# --- Compilación del Modelo ---
# Usamos el optimizador y la pérdida que ya habías afinado
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model_cnn.compile(optimizer=adam_optimizer,
                  loss='mean_absolute_error', # MAE es bueno para regresión
                  metrics=['mae'])

# Imprimir un resumen del modelo para ver la arquitectura
#model_cnn.summary()

SAVE_DIR = "models"
os.makedirs(SAVE_DIR, exist_ok=True)

best_model_filepath = os.path.join(SAVE_DIR, "best_model.keras")

model_checkpoint_callback = ModelCheckpoint(
    filepath=best_model_filepath, # <-- Path estático
    save_weights_only=False, # Guarda el modelo completo
    monitor='val_loss',
    mode='min', # Queremos minimizar el 'val_loss'
    save_best_only=True, # ¡La parte más importante!
    verbose=1)

# --- Entrenamiento del Modelo ---
print("\nIniciando entrenamiento del modelo 1D-CNN...")
history_cnn = model_cnn.fit(
    X_train,  # <-- Usar los datos reformateados
    y_train,
    epochs=100,
    batch_size=64, # 64 es un buen tamaño
    validation_data=(X_val, y_val), # <-- Usar los datos reformateados
    verbose=1,
    callbacks=[model_checkpoint_callback] # <-- ¡Añadido el callback!
)

print("\nEntrenamiento completado.")
print(f"El mejor modelo ha sido guardado en el directorio: {best_model_filepath}")
# Out:
# Construyendo modelo 1D-CNN con input_shape: (100, 1)
#
# Iniciando entrenamiento del modelo 1D-CNN...
# Epoch 1/100
# /opt/miniconda3/envs/gly_models/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 47/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 473.9847 - mae: 473.9847
# Epoch 1: val_loss improved from None to 263.96277, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 400.8550 - mae: 400.8550 - val_loss: 263.9628 - val_mae: 263.9628
# Epoch 2/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 250.7584 - mae: 250.7584
# Epoch 2: val_loss improved from 263.96277 to 228.31682, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 236.6529 - mae: 236.6529 - val_loss: 228.3168 - val_mae: 228.3168
# Epoch 3/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 219.3070 - mae: 219.3070
# Epoch 3: val_loss improved from 228.31682 to 209.51857, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 214.2410 - mae: 214.2410 - val_loss: 209.5186 - val_mae: 209.5186
# Epoch 4/100
# 45/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 200.8058 - mae: 200.8058
# Epoch 4: val_loss improved from 209.51857 to 193.19284, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 199.2711 - mae: 199.2711 - val_loss: 193.1928 - val_mae: 193.1928
# Epoch 5/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 185.3777 - mae: 185.3777
# Epoch 5: val_loss improved from 193.19284 to 162.67241, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 178.9720 - mae: 178.9720 - val_loss: 162.6724 - val_mae: 162.6724
# Epoch 6/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 157.9116 - mae: 157.9116
# Epoch 6: val_loss improved from 162.67241 to 127.69576, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 150.2837 - mae: 150.2837 - val_loss: 127.6958 - val_mae: 127.6958
# Epoch 7/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 124.6577 - mae: 124.6577
# Epoch 7: val_loss improved from 127.69576 to 88.14817, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 115.3092 - mae: 115.3092 - val_loss: 88.1482 - val_mae: 88.1482
# Epoch 8/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 102.1537 - mae: 102.1537
# Epoch 8: val_loss improved from 88.14817 to 84.48499, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 100.8768 - mae: 100.8768 - val_loss: 84.4850 - val_mae: 84.4850
# Epoch 9/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 97.8487 - mae: 97.8487
# Epoch 9: val_loss improved from 84.48499 to 77.57395, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 94.8061 - mae: 94.8061 - val_loss: 77.5740 - val_mae: 77.5740
# Epoch 10/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 94.2625 - mae: 94.2625
# Epoch 10: val_loss did not improve from 77.57395
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 93.8932 - mae: 93.8932 - val_loss: 78.0861 - val_mae: 78.0861
# Epoch 11/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 88.3070 - mae: 88.3070
# Epoch 11: val_loss improved from 77.57395 to 76.93858, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 89.8287 - mae: 89.8287 - val_loss: 76.9386 - val_mae: 76.9386
# Epoch 12/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.4869 - mae: 89.4869
# Epoch 12: val_loss improved from 76.93858 to 76.63980, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 90.8842 - mae: 90.8842 - val_loss: 76.6398 - val_mae: 76.6398
# Epoch 13/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.1308 - mae: 89.1308
# Epoch 13: val_loss improved from 76.63980 to 75.91060, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 91.2410 - mae: 91.2410 - val_loss: 75.9106 - val_mae: 75.9106
# Epoch 14/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.2583 - mae: 89.2583
# Epoch 14: val_loss improved from 75.91060 to 75.57137, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 91.5984 - mae: 91.5984 - val_loss: 75.5714 - val_mae: 75.5714
# Epoch 15/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 90.5382 - mae: 90.5382
# Epoch 15: val_loss improved from 75.57137 to 74.57712, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 90.4500 - mae: 90.4500 - val_loss: 74.5771 - val_mae: 74.5771
# Epoch 16/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 88.6440 - mae: 88.6440
# Epoch 16: val_loss improved from 74.57712 to 74.45847, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 91.1299 - mae: 91.1299 - val_loss: 74.4585 - val_mae: 74.4585
# Epoch 17/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 91.4792 - mae: 91.4792
# Epoch 17: val_loss improved from 74.45847 to 71.05397, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 89.6169 - mae: 89.6169 - val_loss: 71.0540 - val_mae: 71.0540
# Epoch 18/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 86.7766 - mae: 86.7766
# Epoch 18: val_loss improved from 71.05397 to 70.15999, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 86.5528 - mae: 86.5528 - val_loss: 70.1600 - val_mae: 70.1600
# Epoch 19/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 86.9260 - mae: 86.9260
# Epoch 19: val_loss improved from 70.15999 to 68.77031, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 86.8598 - mae: 86.8598 - val_loss: 68.7703 - val_mae: 68.7703
# Epoch 20/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 85.7571 - mae: 85.7571
# Epoch 20: val_loss did not improve from 68.77031
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 86.6581 - mae: 86.6581 - val_loss: 71.9255 - val_mae: 71.9255
# Epoch 21/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 88.2045 - mae: 88.2045
# Epoch 21: val_loss improved from 68.77031 to 66.51213, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 87.6634 - mae: 87.6634 - val_loss: 66.5121 - val_mae: 66.5121
# Epoch 22/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 85.8167 - mae: 85.8167
# Epoch 22: val_loss did not improve from 66.51213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 85.2089 - mae: 85.2089 - val_loss: 67.9120 - val_mae: 67.9120
# Epoch 23/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.6566 - mae: 82.6566
# Epoch 23: val_loss did not improve from 66.51213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 84.0024 - mae: 84.0024 - val_loss: 76.4028 - val_mae: 76.4028
# Epoch 24/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 87.0894 - mae: 87.0894
# Epoch 24: val_loss improved from 66.51213 to 65.79900, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 84.1552 - mae: 84.1552 - val_loss: 65.7990 - val_mae: 65.7990
# Epoch 25/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.7825 - mae: 82.7825
# Epoch 25: val_loss improved from 65.79900 to 62.00177, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 82.9095 - mae: 82.9095 - val_loss: 62.0018 - val_mae: 62.0018
# Epoch 26/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.8989 - mae: 82.8989
# Epoch 26: val_loss did not improve from 62.00177
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 82.7990 - mae: 82.7990 - val_loss: 72.2000 - val_mae: 72.2000
# Epoch 27/100
# 45/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.4392 - mae: 82.4392
# Epoch 27: val_loss improved from 62.00177 to 59.82813, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 81.2445 - mae: 81.2445 - val_loss: 59.8281 - val_mae: 59.8281
# Epoch 28/100
# 39/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 78.6065 - mae: 78.6065
# Epoch 28: val_loss did not improve from 59.82813
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 81.4541 - mae: 81.4541 - val_loss: 66.8437 - val_mae: 66.8437
# Epoch 29/100
# 44/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 78.3521 - mae: 78.3521
# Epoch 29: val_loss did not improve from 59.82813
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 77.6166 - mae: 77.6166 - val_loss: 61.4788 - val_mae: 61.4788
# Epoch 30/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 77.2320 - mae: 77.2320
# Epoch 30: val_loss improved from 59.82813 to 58.58113, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 77.1339 - mae: 77.1339 - val_loss: 58.5811 - val_mae: 58.5811
# Epoch 31/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 76.6227 - mae: 76.6227
# Epoch 31: val_loss did not improve from 58.58113
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 76.3186 - mae: 76.3186 - val_loss: 59.7591 - val_mae: 59.7591
# Epoch 32/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 78.0785 - mae: 78.0785
# Epoch 32: val_loss improved from 58.58113 to 56.58941, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 78.6232 - mae: 78.6232 - val_loss: 56.5894 - val_mae: 56.5894
# Epoch 33/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.8347 - mae: 75.8347
# Epoch 33: val_loss improved from 56.58941 to 55.46825, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 76.6636 - mae: 76.6636 - val_loss: 55.4683 - val_mae: 55.4683
# Epoch 34/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 74.2263 - mae: 74.2263
# Epoch 34: val_loss improved from 55.46825 to 53.25056, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 75.7106 - mae: 75.7106 - val_loss: 53.2506 - val_mae: 53.2506
# Epoch 35/100
# 43/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 74.4959 - mae: 74.4959
# Epoch 35: val_loss did not improve from 53.25056
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 75.6651 - mae: 75.6651 - val_loss: 55.9033 - val_mae: 55.9033
# Epoch 36/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 73.1234 - mae: 73.1234
# Epoch 36: val_loss did not improve from 53.25056
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.6735 - mae: 73.6735 - val_loss: 59.6877 - val_mae: 59.6877
# Epoch 37/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 74.4322 - mae: 74.4322
# Epoch 37: val_loss did not improve from 53.25056
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 74.7587 - mae: 74.7587 - val_loss: 66.3807 - val_mae: 66.3807
# Epoch 38/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 75.7415 - mae: 75.7415
# Epoch 38: val_loss did not improve from 53.25056
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.7453 - mae: 73.7453 - val_loss: 57.6207 - val_mae: 57.6207
# Epoch 39/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 73.9582 - mae: 73.9582
# Epoch 39: val_loss did not improve from 53.25056
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.3547 - mae: 73.3547 - val_loss: 56.6751 - val_mae: 56.6751
# Epoch 40/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 72.2210 - mae: 72.2210
# Epoch 40: val_loss improved from 53.25056 to 50.67501, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 72.5819 - mae: 72.5819 - val_loss: 50.6750 - val_mae: 50.6750
# Epoch 41/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.4601 - mae: 73.4601
# Epoch 41: val_loss did not improve from 50.67501
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 75.2560 - mae: 75.2560 - val_loss: 65.2059 - val_mae: 65.2059
# Epoch 42/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 74.0058 - mae: 74.0058
# Epoch 42: val_loss did not improve from 50.67501
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 74.3153 - mae: 74.3153 - val_loss: 55.4646 - val_mae: 55.4646
# Epoch 43/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 71.1178 - mae: 71.1178
# Epoch 43: val_loss did not improve from 50.67501
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71.6450 - mae: 71.6450 - val_loss: 50.8241 - val_mae: 50.8241
# Epoch 44/100
# 36/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 72.1454 - mae: 72.1454
# Epoch 44: val_loss did not improve from 50.67501
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 71.6527 - mae: 71.6527 - val_loss: 54.8739 - val_mae: 54.8739
# Epoch 45/100
# 39/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.3958 - mae: 70.3958
# Epoch 45: val_loss improved from 50.67501 to 49.56511, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 71.8297 - mae: 71.8297 - val_loss: 49.5651 - val_mae: 49.5651
# Epoch 46/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71.0846 - mae: 71.0846
# Epoch 46: val_loss did not improve from 49.56511
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71.1334 - mae: 71.1334 - val_loss: 51.0243 - val_mae: 51.0243
# Epoch 47/100
# 38/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.7464 - mae: 68.7464
# Epoch 47: val_loss improved from 49.56511 to 48.64014, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69.5505 - mae: 69.5505 - val_loss: 48.6401 - val_mae: 48.6401
# Epoch 48/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71.0257 - mae: 71.0257
# Epoch 48: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.8833 - mae: 69.8833 - val_loss: 55.7533 - val_mae: 55.7533
# Epoch 49/100
# 39/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.9300 - mae: 69.9300
# Epoch 49: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.0129 - mae: 69.0129 - val_loss: 49.4286 - val_mae: 49.4286
# Epoch 50/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.4915 - mae: 68.4915
# Epoch 50: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.4123 - mae: 69.4123 - val_loss: 49.4961 - val_mae: 49.4961
# Epoch 51/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.5393 - mae: 68.5393
# Epoch 51: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.3602 - mae: 69.3602 - val_loss: 49.0592 - val_mae: 49.0592
# Epoch 52/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.5032 - mae: 69.5032
# Epoch 52: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.5188 - mae: 70.5188 - val_loss: 51.1260 - val_mae: 51.1260
# Epoch 53/100
# 42/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71.2569 - mae: 71.2569
# Epoch 53: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.4742 - mae: 70.4742 - val_loss: 53.3135 - val_mae: 53.3135
# Epoch 54/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.7897 - mae: 68.7897
# Epoch 54: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69.5302 - mae: 69.5302 - val_loss: 58.8800 - val_mae: 58.8800
# Epoch 55/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 71.5454 - mae: 71.5454
# Epoch 55: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.0369 - mae: 70.0369 - val_loss: 49.4001 - val_mae: 49.4001
# Epoch 56/100
# 38/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.6274 - mae: 68.6274
# Epoch 56: val_loss did not improve from 48.64014
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.6535 - mae: 68.6535 - val_loss: 53.0503 - val_mae: 53.0503
# Epoch 57/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.5933 - mae: 68.5933
# Epoch 57: val_loss improved from 48.64014 to 48.03898, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.6423 - mae: 69.6423 - val_loss: 48.0390 - val_mae: 48.0390
# Epoch 58/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.0676 - mae: 69.0676
# Epoch 58: val_loss did not improve from 48.03898
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68.6956 - mae: 68.6956 - val_loss: 50.3142 - val_mae: 50.3142
# Epoch 59/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.2094 - mae: 68.2094
# Epoch 59: val_loss did not improve from 48.03898
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.8140 - mae: 67.8140 - val_loss: 51.6609 - val_mae: 51.6609
# Epoch 60/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.7819 - mae: 68.7819
# Epoch 60: val_loss did not improve from 48.03898
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69.5698 - mae: 69.5698 - val_loss: 51.9871 - val_mae: 51.9871
# Epoch 61/100
# 30/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.8829 - mae: 67.8829
# Epoch 61: val_loss did not improve from 48.03898
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68.8718 - mae: 68.8718 - val_loss: 52.5715 - val_mae: 52.5715
# Epoch 62/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.6188 - mae: 68.6188
# Epoch 62: val_loss improved from 48.03898 to 46.71139, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68.4337 - mae: 68.4337 - val_loss: 46.7114 - val_mae: 46.7114
# Epoch 63/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.1269 - mae: 70.1269
# Epoch 63: val_loss improved from 46.71139 to 46.49213, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 69.1504 - mae: 69.1504 - val_loss: 46.4921 - val_mae: 46.4921
# Epoch 64/100
# 39/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.0140 - mae: 67.0140
# Epoch 64: val_loss improved from 46.49213 to 45.76137, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.7066 - mae: 67.7066 - val_loss: 45.7614 - val_mae: 45.7614
# Epoch 65/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.6677 - mae: 68.6677
# Epoch 65: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.5070 - mae: 67.5070 - val_loss: 48.2566 - val_mae: 48.2566
# Epoch 66/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.7492 - mae: 67.7492
# Epoch 66: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.4585 - mae: 68.4585 - val_loss: 48.7253 - val_mae: 48.7253
# Epoch 67/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.3643 - mae: 70.3643
# Epoch 67: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 72.0453 - mae: 72.0453 - val_loss: 49.6749 - val_mae: 49.6749
# Epoch 68/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.6075 - mae: 66.6075
# Epoch 68: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.7874 - mae: 67.7874 - val_loss: 48.8385 - val_mae: 48.8385
# Epoch 69/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.1281 - mae: 65.1281
# Epoch 69: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.2534 - mae: 67.2534 - val_loss: 50.6715 - val_mae: 50.6715
# Epoch 70/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.1108 - mae: 64.1108
# Epoch 70: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.0547 - mae: 66.0547 - val_loss: 56.0132 - val_mae: 56.0132
# Epoch 71/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.8416 - mae: 65.8416
# Epoch 71: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.2950 - mae: 67.2950 - val_loss: 48.2385 - val_mae: 48.2385
# Epoch 72/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.2448 - mae: 67.2448
# Epoch 72: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.7657 - mae: 67.7657 - val_loss: 52.2310 - val_mae: 52.2310
# Epoch 73/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.2451 - mae: 66.2451
# Epoch 73: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.5015 - mae: 66.5015 - val_loss: 50.6432 - val_mae: 50.6432
# Epoch 74/100
# 36/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.6005 - mae: 69.6005
# Epoch 74: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68.2015 - mae: 68.2015 - val_loss: 46.6645 - val_mae: 46.6645
# Epoch 75/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.1367 - mae: 69.1367
# Epoch 75: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.8595 - mae: 67.8595 - val_loss: 50.5144 - val_mae: 50.5144
# Epoch 76/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.6312 - mae: 67.6312
# Epoch 76: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.5162 - mae: 68.5162 - val_loss: 47.0127 - val_mae: 47.0127
# Epoch 77/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.7745 - mae: 66.7745
# Epoch 77: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 67.8840 - mae: 67.8840 - val_loss: 52.7495 - val_mae: 52.7495
# Epoch 78/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.1567 - mae: 68.1567
# Epoch 78: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 66.4264 - mae: 66.4264 - val_loss: 46.2444 - val_mae: 46.2444
# Epoch 79/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.8238 - mae: 65.8238
# Epoch 79: val_loss did not improve from 45.76137
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.7488 - mae: 64.7488 - val_loss: 47.7122 - val_mae: 47.7122
# Epoch 80/100
# 36/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67.0898 - mae: 67.0898
# Epoch 80: val_loss improved from 45.76137 to 42.57392, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 66.2836 - mae: 66.2836 - val_loss: 42.5739 - val_mae: 42.5739
# Epoch 81/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.3273 - mae: 65.3273
# Epoch 81: val_loss did not improve from 42.57392
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 65.9522 - mae: 65.9522 - val_loss: 55.5465 - val_mae: 55.5465
# Epoch 82/100
# 38/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.8607 - mae: 64.8607
# Epoch 82: val_loss did not improve from 42.57392
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.0378 - mae: 65.0378 - val_loss: 49.3053 - val_mae: 49.3053
# Epoch 83/100
# 36/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.1141 - mae: 62.1141
# Epoch 83: val_loss did not improve from 42.57392
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.7731 - mae: 63.7731 - val_loss: 43.3222 - val_mae: 43.3222
# Epoch 84/100
# 36/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.4449 - mae: 64.4449
# Epoch 84: val_loss did not improve from 42.57392
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 65.5484 - mae: 65.5484 - val_loss: 45.0318 - val_mae: 45.0318
# Epoch 85/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.8270 - mae: 62.8270
# Epoch 85: val_loss did not improve from 42.57392
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.1511 - mae: 63.1511 - val_loss: 45.9043 - val_mae: 45.9043
# Epoch 86/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.3564 - mae: 64.3564
# Epoch 86: val_loss did not improve from 42.57392
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 64.1234 - mae: 64.1234 - val_loss: 47.5673 - val_mae: 47.5673
# Epoch 87/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.8326 - mae: 63.8326
# Epoch 87: val_loss did not improve from 42.57392
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.8865 - mae: 63.8865 - val_loss: 42.7216 - val_mae: 42.7216
# Epoch 88/100
# 41/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.8368 - mae: 64.8368
# Epoch 88: val_loss improved from 42.57392 to 41.83939, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.7819 - mae: 63.7819 - val_loss: 41.8394 - val_mae: 41.8394
# Epoch 89/100
# 39/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.7869 - mae: 65.7869
# Epoch 89: val_loss did not improve from 41.83939
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65.3779 - mae: 65.3779 - val_loss: 43.9840 - val_mae: 43.9840
# Epoch 90/100
# 36/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.2881 - mae: 66.2881
# Epoch 90: val_loss did not improve from 41.83939
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 64.7073 - mae: 64.7073 - val_loss: 43.7033 - val_mae: 43.7033
# Epoch 91/100
# 36/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.2220 - mae: 64.2220
# Epoch 91: val_loss did not improve from 41.83939
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 64.7447 - mae: 64.7447 - val_loss: 46.8892 - val_mae: 46.8892
# Epoch 92/100
# 35/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 61.1865 - mae: 61.1865
# Epoch 92: val_loss did not improve from 41.83939
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.3243 - mae: 63.3243 - val_loss: 47.0113 - val_mae: 47.0113
# Epoch 93/100
# 39/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66.3666 - mae: 66.3666
# Epoch 93: val_loss did not improve from 41.83939
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 65.6338 - mae: 65.6338 - val_loss: 45.8081 - val_mae: 45.8081
# Epoch 94/100
# 40/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.4771 - mae: 63.4771
# Epoch 94: val_loss did not improve from 41.83939
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.4370 - mae: 64.4370 - val_loss: 45.5275 - val_mae: 45.5275
# Epoch 95/100
# 37/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.0320 - mae: 64.0320
# Epoch 95: val_loss improved from 41.83939 to 41.67382, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 64.3165 - mae: 64.3165 - val_loss: 41.6738 - val_mae: 41.6738
# Epoch 96/100
# 35/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.9364 - mae: 62.9364
# Epoch 96: val_loss did not improve from 41.67382
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 62.6403 - mae: 62.6403 - val_loss: 43.2291 - val_mae: 43.2291
# Epoch 97/100
# 35/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.7378 - mae: 63.7378
# Epoch 97: val_loss did not improve from 41.67382
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 65.2877 - mae: 65.2877 - val_loss: 49.9252 - val_mae: 49.9252
# Epoch 98/100
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.7657 - mae: 63.7657
# Epoch 98: val_loss did not improve from 41.67382
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.0049 - mae: 63.0049 - val_loss: 41.8284 - val_mae: 41.8284
# Epoch 99/100
# 35/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.2772 - mae: 62.2772
# Epoch 99: val_loss improved from 41.67382 to 41.14305, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.3975 - mae: 63.3975 - val_loss: 41.1431 - val_mae: 41.1431
# Epoch 100/100
# 35/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.4219 - mae: 63.4219
# Epoch 100: val_loss improved from 41.14305 to 40.95956, saving model to models/best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 63.7832 - mae: 63.7832 - val_loss: 40.9596 - val_mae: 40.9596
#
# Entrenamiento completado.
# El mejor modelo ha sido guardado en el directorio: models/best_model.keras

# %% [markdown]
# ### first R

# %%
# File path with measurements 
file_path = '/Users/andresmr/Documents/Glyphosate_sensor_CFATA/samples/G2R2R3.csv'
#file_path = '/Users/andresmr/Documents/Glyphosate_sensor_CFATA/ESP32_code/samples/G2.csv'


# Open file with data. 
with open(file_path, 'r') as file:
    reader = csv.reader(file)
    n = 0
    test_data = []
    for i,row in enumerate(reader):
        test_data.append(row)
        # if n>=int(split[1]-1):
        #     test_data.append(row)
        # n+=1

_test_inputs = []
_test_targets = []

# Add first block of data (original)
for i in range(len(test_data)):
        row_data = []
        for j in range(3,104):
                if j!= 53:
                #if j>53:                       
                        row_data.append(float(test_data[i][j]))
        _test_inputs.append(row_data)
        _test_targets.append(float(test_data[i][1]))

# Convert list to arrays
X_test = np.array(_test_inputs)
y_test= np.array(_test_targets)

print(len(X_test), len(y_test), len(X_test[0]))
X_test_scaled = scaler.transform(X_test)

X_test = X_test_scaled.reshape((X_test.shape[0], X_test.shape[1], 1))

model_predict(best_model_filepath,X_test_scaled,y_test)
# Out:
# 131 131 100
# Loading model from: models/best_model.keras
# Model loaded successfully.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# [ 76.5931   107.45768   89.40317   14.274109  38.14622   23.675995]
# 58.258377 34.789337
# (LOD): 162.6264 ppm
# (LOQ): 406.1517 ppm
# Mean Absolute Error (MAE): 95.078
# Root Mean Squared Error (RMSE): 110.669
# R-squared (R2): 0.949
